# %%
#welcome
name = input("Enter your name: ")
print("What's up %s, want to play hangman?" % name)
answer = input("Yes or No: ")
game = 0
while game == 0:
    if answer == "Yes":
        break
    if answer == "yes":
        break
    else:
        print("See you later")
print("")

#countdown to play
import time
time.sleep(0.1)
print("Loading...")
time.sleep(1)
print("3")
time.sleep(1)
print("2")
time.sleep(1)
print("1")
time.sleep(1)
print("")
print("Let's play!")

#game
import random
fruit = ("pineapple", "starfruit", "papaya", "dragonfruit", "jackfruit",  "lychee")
randomwords = ("xylophone","atrocious","spectacular")
languages = ("french","vietnamese","english","chinese","hindu","korean")
colors = ("burgundy","turquoise","maroon","violet","lavender","mint")
ice_cream_flavors = ("chocolate","vanilla","strawberry","matcha","coconut","taro")


alist = (fruit,randomwords,languages,colors)
aalist = random.choice(alist)
word = random.choice(aalist)

print("")
time.sleep(0.2)

if aalist == fruit:
    print("Your topic is: fruit")
elif aalist == randomwords:
    print("Your topic includes random words, good luck :D")
elif aalist == languages:
    print("Your topic is: languages(in lower case)")
elif aalist == colors:
    print("Your topic is: color")
elif aalist == ice_cream_flavors:
    print("Your topic is: ice cream flavors")
    
guesses = ''
turns = 6 #head,body,legs,arms

#gameplay
while turns > 0:         
    fail = 0             
    for char in word:      
        if char in guesses:    
            print(char)    
        else:
            print("_")     
            fail += 1    
    if fail == 0:        
        print("Congratulations %s, you won!" % name)
        break              
    guess = input("Guess a character:") 
    guesses += guess
    
    if guess not in word:  
        turns -= 1        
        print("Wrong")  
        print("You have %d more guesses" % turns)
        if turns == 0:           
            print("You have lost, try again!")
# Out:
# Enter your name: Kyle
# What's up Kyle, want to play hangman?
# Yes or No: Yes
#
# Loading...
# 3
# 2
# 1
#
# Let's play!
#
# Your topic is: color
# _
# _
# _
# _
# _
# _
# _
# _
# _
# Guess a character:a
# Wrong
# You have 5 more guesses
# _
# _
# _
# _
# _
# _
# _
# _
# _
# Guess a character:t
# t
# _
# _
# _
# _
# _
# _
# _
# _
# Guess a character:u
# t
# u
# _
# _
# u
# _
# _
# _
# _
# Guess a character:r
# t
# u
# r
# _
# u
# _
# _
# _
# _
# Guess a character:q
# t
# u
# r
# q
# u
# _
# _
# _
# _
# Guess a character:o
# t
# u
# r
# q
# u
# o
# _
# _
# _
# Guess a character:i
# t
# u
# r
# q
# u
# o
# i
# _
# _
# Guess a character:s
# t
# u
# r
# q
# u
# o
# i
# s
# _
# Guess a character:e
# t
# u
# r
# q
# u
# o
# i
# s
# e
# Congratulations Kyle, you won!
